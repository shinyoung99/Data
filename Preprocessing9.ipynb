# %% [markdown]
# <a href="https://colab.research.google.com/github/shinyoung99/Data/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

base_url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
method = "download"
url = "{0}?method={1}".format(base_url, method)

df = pd.read_html(url, header = 0)[0]

with pd.option_context('display.max_columns', 4):
  pd.set_option("show_dimensions", False)
  display(df.head(10))
# Out:
#       회사명    종목코드  ...                        홈페이지     지역
# 0  BGF리테일  282330  ...    http://www.bgfretail.com  서울특별시
# 1  CJ제일제당   97950  ...         http://www.cj.co.kr  서울특별시
# 2   DRB동일    4840  ...     http://www.drbworld.com  부산광역시
# 3      E1   17940  ...         http://www.e1.co.kr  서울특별시
# 4     HDC   12630  ...       http://www.i-park.com  서울특별시
# 5  KPX홀딩스   92230  ...  http://www.kpxholdings.com  서울특별시
# 6    LG화학   51910  ...       http://www.lgchem.com  서울특별시
# 7  LIG넥스원   79550  ...      http://www.lignex1.com    경기도
# 8   NAVER   35420  ...    http://www.navercorp.com    경기도
# 9  NH올원리츠  400760  ...      http://www.nhreits.com  서울특별시

# %%
df['종목코드'] = df['종목코드'].apply(lambda x: f"{x:06d}")

with pd.option_context('display.max_columns', 4):
    pd.set_option("show_dimensions", False)
    display(df.head())
# Out:
#       회사명    종목코드  ...                      홈페이지     지역
# 0  BGF리테일  282330  ...  http://www.bgfretail.com  서울특별시
# 1  CJ제일제당  097950  ...       http://www.cj.co.kr  서울특별시
# 2   DRB동일  004840  ...   http://www.drbworld.com  부산광역시
# 3      E1  017940  ...       http://www.e1.co.kr  서울특별시
# 4     HDC  012630  ...     http://www.i-park.com  서울특별시

# %%
def get_stock_code(company_name, maket_type = None):
    df = get_stock_info(maket_type)
    code = df[df['']]
