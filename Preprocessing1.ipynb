# %% [markdown]
# <a href="https://colab.research.google.com/github/shinyoung99/Data/blob/main/Preprocessing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = {'Name':['Kim', 'Park', 'Lee', 'Choi'],
'Age':[20, 23, 21, 26]}
df = pd.DataFrame(data, index=["학번 1", "학번2", "학번3", "학번 4"])
df
# Out:
#       Name  Age
# 학번 1   Kim   20
# 학번2   Park   23
# 학번3    Lee   21
# 학번 4  Choi   26

# %%
titanic = pd.read_csv("titanic.csv", index_col=0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic.to_excel('titanic.xlsx', sheet_name='passngers', index=False)

titanic = pd.read_excel('titanic.xlsx', sheet_name='passngers')

# %%
import numpy as np

df =pd.DataFrame(np.random.randint(0, 100, size=(5,4)), columns=list('ABCD'))
df
# Out:
#     A   B   C   D
# 0  55  33  87  87
# 1  41  29  46  53
# 2  79  90  15  94
# 3  69  76  28  13
# 4  73  49  11   2

# %%
import pandas as pd
countries = pd.read_csv('countries.csv')

countries
# Out:
#   code country      area     capital  population
# 0   KR   Korea     98480       Seoul    48422644
# 1   US     USA   9629091  Washington   310232863
# 2   JP   Japan    377835       Tokyo   127288000
# 3   CN   China   9596960     Beijing  1330044000
# 4   RU  Russia  17100000      Moscow   140702000

# %%
ages = titanic["Age"]
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
titanic[["Name", "Age", "Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
below_20 = titanic[titanic["Age"] < 20]
below_20.head()
# Out:
#     Survived  Pclass                                  Name     Sex   Age  \
# 7          0       3        Palsson, Master. Gosta Leonard    male   2.0
# 9          1       2   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10         1       3       Sandstrom, Miss. Marguerite Rut  female   4.0
# 14         0       3  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16         0       3                  Rice, Master. Eugene    male   2.0
#
#     SibSp  Parch   Ticket     Fare Cabin Embarked
# 7       3      1   349909  21.0750   NaN        S
# 9       1      0   237736  30.0708   NaN        C
# 10      1      1  PP 9549  16.7000    G6        S
# 14      0      0   350406   7.8542   NaN        S
# 16      4      1   382652  29.1250   NaN        Q

# %%
titanic[titanic["Pclass"].isin([1, 2])]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                            McCarthy, Mr. Timothy J
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 11          1       1                           Bonnell, Miss. Elizabeth
# ..        ...     ...                                                ...
# 880         1       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 883         0       2                      Banfield, Mr. Frederick James
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.loc[titanic["Age"] < 20, "Name"]
# Out:
# 7            Palsson, Master. Gosta Leonard
# 9       Nasser, Mrs. Nicholas (Adele Achem)
# 10          Sandstrom, Miss. Marguerite Rut
# 14     Vestrom, Miss. Hulda Amanda Adolfina
# 16                     Rice, Master. Eugene
#                        ...
# 855              Aks, Mrs. Sam (Leah Rosen)
# 869         Johnson, Master. Harold Theodor
# 875        Najib, Miss. Adele Kiamie "Jane"
# 877                    Petroff, Mr. Nedelio
# 887            Graham, Miss. Margaret Edith
# Name: Name, Length: 164, dtype: object

# %%
titanic.iloc[20:23, 5:7]
# Out:
#     SibSp  Parch
# 20      0      0
# 21      0      0
# 22      0      0

# %%
titanic.sort_values(by="Age").head()
# Out:
#      Survived  Pclass                             Name     Sex   Age  SibSp  \
# 803         1       3  Thomas, Master. Assad Alexander    male  0.42      0
# 755         1       2        Hamalainen, Master. Viljo    male  0.67      1
# 644         1       3           Baclini, Miss. Eugenie  female  0.75      2
# 469         1       3    Baclini, Miss. Helene Barbara  female  0.75      2
# 78          1       2    Caldwell, Master. Alden Gates    male  0.83      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 803      1    2625   8.5167   NaN        C
# 755      1  250649  14.5000   NaN        S
# 644      1    2666  19.2583   NaN        C
# 469      1    2666  19.2583   NaN        C
# 78       2  248738  29.0000   NaN        S

# %%
titanic.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#      Survived  Pclass                       Name     Sex   Age  SibSp  Parch  \
# 851         0       3        Svensson, Mr. Johan    male  74.0      0      0
# 116         0       3       Connors, Mr. Patrick    male  70.5      0      0
# 280         0       3           Duane, Mr. Frank    male  65.0      0      0
# 483         1       3     Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 326         0       3  Nysveen, Mr. Johan Hansen    male  61.0      0      0
#
#      Ticket    Fare Cabin Embarked
# 851  347060  7.7750   NaN        S
# 116  370369  7.7500   NaN        Q
# 280  336439  7.7500   NaN        Q
# 483    4134  9.5875   NaN        S
# 326  345364  6.2375   NaN        S

# %%
import pandas as pd

countries = pd.read_csv('countries.csv')
countries["density"] = countries['population']/countries["area"]
countries
# Out:
#   code country      area     capital  population     density
# 0   KR   Korea     98480       Seoul    48422644  491.700284
# 1   US     USA   9629091  Washington   310232863   32.218292
# 2   JP   Japan    377835       Tokyo   127288000  336.887795
# 3   CN   China   9596960     Beijing  1330044000  138.590137
# 4   RU  Russia  17100000      Moscow   140702000    8.228187

# %%
df = pd.DataFrame({"code":["CA"], "country":["Canada"], "area":[9984670], "capital":["Ottawa"],"population": [34300000]})

df2 = countries.append(df, ignore_index = True)
df2
# Out:
# <ipython-input-31-15647f2a15fa>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = countries.append(df, ignore_index = True)
#   code country      area     capital  population     density
# 0   KR   Korea     98480       Seoul    48422644  491.700284
# 1   US     USA   9629091  Washington   310232863   32.218292
# 2   JP   Japan    377835       Tokyo   127288000  336.887795
# 3   CN   China   9596960     Beijing  1330044000  138.590137
# 4   RU  Russia  17100000      Moscow   140702000    8.228187
# 5   CA  Canada   9984670      Ottawa    34300000         NaN

# %%
# countries.drop(index=2, axis=0, inplace = True)
countries
# Out:
#   code country      area     capital  population     density
# 0   KR   Korea     98480       Seoul    48422644  491.700284
# 1   US     USA   9629091  Washington   310232863   32.218292
# 3   CN   China   9596960     Beijing  1330044000  138.590137
# 4   RU  Russia  17100000      Moscow   140702000    8.228187

# %%
countries.drop(["capital"], axis=1, inplace = True)

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({
    'name':['Kim','Lee', 'Park','Choi', 'Hong', 'Chung','Jang'],
    'age':[22,26,78,17,46,32,21],
    'city':['Seoul','Busan','Seoul','Busan','Seoul', 'Daejun', 'Daejun'],
    'children':[2,3,0,1,3,4,3],
    'pets':[0,1,0,2,2,0,3,]
})

# %%
df.plot(kind='line', x ='name', y ='pets', color='red')
plt.show

# %%
ax = plt.gca()#get current axis

df.plot(kind='line','x'='name', 'y'='children',ax=ax)
df.plot(kind='line',x='name',y='chiildren')

# %%
df.plot(kind='bar', x='name', y='age')
plt.show()

# %%
df.plot(kind='scatter', x='children', y='age')
plt.show()

# %%
df.groupby('city')['name'].nunique().plot(kind='bar')
plt.show()

# %%
import pandas as pd
item = pd.read_csv("item.csv")
item
# Out:
#     item    type  price
# 0  ring0    Gold  20000
# 1  ring0  Silver  10000
# 2  ring1    Gold  50000
# 3  ring1  Bronze  30000

# %%
item = pd.read_csv("item.csv", index_col=2)
item
# Out:
#         item    type
# price
# 20000  ring0    Gold
# 10000  ring0  Silver
# 50000  ring1    Gold
# 30000  ring1  Bronze

# %%
item1 = item.set_index('item', inplace=True)

# %%
item1 = item.pivot(columns = 'type', values= 'price')

# %%
item1
# Out:
# type    Bronze     Gold   Silver
# item
# ring0      NaN  20000.0  10000.0
# ring1  30000.0  50000.0      NaN

# %%
Countries[["Country", "Popular"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-6b28be27924b> in <cell line: 1>()
# ----> 1 Countries[["Country", "Popular"]]
#
# NameError: name 'Countries' is not defined

# %%
below_20 = countries[countries["Areak"] >100000]
below_20.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Areak'
#
# The above exception was the direct cause of the following exception:
#
# ...
